# %% [markdown]
# <a href="https://colab.research.google.com/github/alifandi-as/Interactive-Python-Notebook-1/blob/main/Alifandi_Praktikum_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Praktikum 01 - Sequential Search pada Data Angka**

# %%
def sequential_search(data, target):
  for i in range(len(data)):
    if data[i] == target:
      return f"Data {target} ditemukan di indeks {i}"
  return f"Data {target} tidak ditemukan"

angka = [10, 20, 30, 40, 50]
print("Data:", angka)
print(sequential_search(angka, 30))
print(sequential_search(angka, 100))
# Out:
# Data: [10, 20, 30, 40, 50]
# Data 30 ditemukan di indeks 2
# Data 100 tidak ditemukan

# %% [markdown]
# # **Praktikum 02 - Binary Search pada Data Angka**

# %%
def binary_search(data, target):
  left, right = 0, len(data)-1
  while left <= right:
    mid = (left + right) // 2
    if data[mid] == target:
      return f"Data {target} ditemukan di indeks {mid}"
    elif data[mid] < target:
      left = mid + 1
    else:
      right = mid - 1
  return f"Data {target} tidak ditemukan"

angka = [10, 20, 30, 40, 50]
print("Data:", angka)
print(binary_search(angka, 40))
print(binary_search(angka, 100))
# Out:
# Data: [10, 20, 30, 40, 50]
# Data 40 ditemukan di indeks 3
# Data 100 tidak ditemukan

# %% [markdown]
# # **Praktikum 03 - Sequential Search untuk Data Nama**

# %%
def sequential_search_nama(data, target):
  for i in range(len(data)):
    if data[i].lower() == target.lower():
      return f"Nama {target} ditemukan di indeks {i}"
    return f"Nama {target} tidak ditemukan"

nama = ["Andi", "Budi", "Cici", "Doni"]
print("Data:", nama)
print(sequential_search_nama(nama, "Cici"))
print(sequential_search_nama(nama, "Eka"))
# Out:
# Data: ['Andi', 'Budi', 'Cici', 'Doni']
# Nama Cici tidak ditemukan
# Nama Eka tidak ditemukan

# %% [markdown]
# # **Praktikum 04 - Studi Kasus Nilai Mahasiswa dengan Binary Search**

# %%
def binary_search_nilai(data, target):
  left, right = 0, len(data)-1
  while left <= right:
    mid = (left + right) // 2
    if data[mid] == target:
      return f"Nilai {target} ditemukan di indeks {mid}"
    elif data[mid] < target:
      left = mid + 1
    else:
      right = mid - 1
  return f"Nilai {target} tidak ditemukan"

nilai = [60, 70, 75, 80, 85, 90]
print("Data nilai:", nilai)
print(binary_search_nilai(nilai, 85))
print(binary_search_nilai(nilai, 65))
# Out:
# Data nilai: [60, 70, 75, 80, 85, 90]
# Nilai 85 ditemukan di indeks 4
# Nilai 65 tidak ditemukan

# %% [markdown]
# # **Praktikum 05 - Perbandingan Waktu Sequential vs Binary Search**

# %%
import time

def sequential_search(data, target):
  for i in range(len(data)):
    if data[i] == target:
      return i
  return -1

def binary_search(data, target):
  left, right = 0, len(data)-1
  while left <= right:
    mid = (left + right) // 2
    if data[mid] == target:
      return mid
    elif data[mid] < target:
      left = mid + 1
    else:
      right = mid - 1
  return -1

data = list(range(1, 100001))
target = 99999

start = time.time()
sequential_search(data, target)
end = time.time()
print("Sequential Search waktu:", end - start, "detik")

start = time.time()
binary_search(data, target)
end = time.time()
print("Binary Search waktu:", end - start, "detik")
# Out:
# Sequential Search waktu: 0.005234956741333008 detik
# Binary Search waktu: 7.128715515136719e-05 detik

# %% [markdown]
# # **Praktikum 06 - Kombinasi Sorting dan Searching**

# %%
import random

def insertion_sort(data):
  for i in range(1, len(data)):
    key = data[i]
    j = i - 1
    while j >= 0 and data[j] > key:
      data[j + 1] = data[j]
      j -= 1
    data[j + 1] = key
  return data

def binary_search(data, target):
  left, right = 0, len(data)-1
  while left <= right:
    mid = (left + right) // 2
    if data[mid] == target:
      return f"{target} ditemukan di indeks {mid}"
    elif data[mid] < target:
      left = mid + 1
    else:
      right = mid - 1
  return f"{target} tidak ditemukan"
data = [random.randint(1, 100) for _ in range(15)]
print("Data acak sebelum diurutkan:", data)
urut = insertion_sort(data)
print("Data setelah diurutkan:", urut)
target = urut[7] # ambil angka ke-8 sebagai target
print(binary_search(urut, target))
# Out:
# Data acak sebelum diurutkan: [62, 12, 64, 2, 97, 65, 25, 76, 41, 86, 22, 31, 81, 81, 95]
# Data setelah diurutkan: [2, 12, 22, 25, 31, 41, 62, 64, 65, 76, 81, 81, 86, 95, 97]
# 64 ditemukan di indeks 7

# %% [markdown]
# # **Penugasan 1: Variasi Sequential Search**

# %%
def sequential_search(data, target):
  operasi = 0
  for i in range(len(data)):
    operasi += 1
    if data[i] == target:
      return f"Data {target} ditemukan di indeks {i}, dibutuhkan {operasi} operasi"
  return f"Data {target} tidak ditemukan"

angka = [10, 20, 30, 40, 50]
print("Data:", angka)
print(sequential_search(angka, 30))
print(sequential_search(angka, 100))
# Out:
# Data: [10, 20, 30, 40, 50]
# Data 30 ditemukan di indeks 2, dibutuhkan 3 operasi
# Data 100 tidak ditemukan

# %% [markdown]
# # **Penugasan 2: Variasi Binary Search**

# %%
def binary_search(data, target):
  left, right = 0, len(data)-1
  operasi = 0
  while left <= right:
    operasi += 1

    mid = (left + right) // 2
    if data[mid] == target:
      return f"Data {target} ditemukan di indeks {mid}, dibutuhkan {operasi} operasi"
    elif data[mid] < target:
      left = mid + 1
    else:
      right = mid - 1

  return f"Data {target} tidak ditemukan"

angka = [10, 20, 30, 40, 50]
print("Data:", angka)
print(binary_search(angka, 40))
print(binary_search(angka, 100))
# Out:
# Data: [10, 20, 30, 40, 50]
# Data 40 ditemukan di indeks 3, dibutuhkan 2 operasi
# Data 100 tidak ditemukan

# %% [markdown]
# # **Penugasan 3: Studi Kasus Nama Mahasiswa**

# %%
def sequential_search(data, target):
  for i in range(len(data)):
    if data[i] == target:
      return f"Data {target} ditemukan di indeks {i}"
  return f"Data {target} tidak ditemukan"

mahasiswa = ["Meri", "Cana", "Melasti", "Endah", "Sampa", "Gunawan", "Inawan", "Setyo"]
cari_siswa = input("Masukkan nama mahasiswa yang akan dicari: ")
print(sequential_search(mahasiswa, cari_siswa))
# Out:
# Masukkan nama mahasiswa yang akan dicari: Gunawan
# Data Gunawan ditemukan di indeks 5

# %% [markdown]
# # **Penugasan 4: Studi Kasus Barang Toko**

# %%
def insertion_sort_key(data, key_index=0, reverse=False):
  n = len(data)
  for i in range(n):
    key = data[i]
    j = i - 1

    while j >= 0 and data[j][key_index] > data[j + 1][key_index]:
      data[j], data[j + 1] = data[j + 1], data[j]
      j -= 1

    data[j + 1] = key
  return data

def binary_search(data, target):
  left, right = 0, len(data)-1
  while left <= right:
    mid = (left + right) // 2
    nama, harga = data[mid]
    if harga == target:
      return f"Barang {nama} ditemukan dengan harga {target}"
    elif harga < target:
      left = mid + 1
    else:
      right = mid - 1
  return f"Barang dengan harga {target} tidak ditemukan"

daftar = [("Sunlight", 5000), ("Sari Gandum", 9000), ("Rice Cooker", 240000), ("Sabun", 7500), ("SanDisk Cruzer 64 GB", 98000)]
daftar = insertion_sort_key(daftar, 1)
print(daftar)

cari = int(input("Masukkan harga barang yang dicari: "))
print(binary_search(daftar, cari))
# Out:
# [('Sunlight', 5000), ('Sabun', 7500), ('Sari Gandum', 9000), ('SanDisk Cruzer 64 GB', 98000), ('Rice Cooker', 240000)]
# Masukkan harga barang yang dicari: 7500
# Barang Sabun ditemukan dengan harga 7500

# %% [markdown]
# # **Penugasan 5: Analisis Kompleksitas**

# %%
import random;

def sequential_search(data, target):
  operasi = 0
  for i in range(len(data)):
    operasi += 1
    if data[i] == target:
      return f"Data {target} ditemukan di indeks {i} ({operasi} operasi)"
  return f"Data {target} tidak ditemukan ({operasi} operasi)"

def binary_search(data, target):
  operasi = 0
  left, right = 0, len(data)-1
  while left <= right:
    operasi += 1
    mid = (left + right) // 2
    if data[mid] == target:
      return f"Data {target} ditemukan di indeks {mid} ({operasi} operasi)"
    elif data[mid] < target:
      left = mid + 1
    else:
      right = mid - 1
  return f"Data {target} tidak ditemukan ({operasi} operasi)"

angka = range(1, 101)
pilih_angka = angka[random.randint(1, 101)];
print(f"Binary search: {binary_search(angka, angka[pilih_angka])}")
print(f"Sequential search: {sequential_search(angka, angka[pilih_angka])}")

angka = range(1, 1001)
pilih_angka = angka[random.randint(1, 1001)];
print(f"Binary search: {binary_search(angka, angka[pilih_angka])}")
print(f"Sequential search: {sequential_search(angka, angka[pilih_angka])}")

angka = range(1, 10001)
pilih_angka = angka[random.randint(1, 10001)];
print(f"Binary search: {binary_search(angka, angka[pilih_angka])}")
print(f"Sequential search: {sequential_search(angka, angka[pilih_angka])}")
# Out:
# Binary search: Data 33 ditemukan di indeks 32 (7 operasi)
# Sequential search: Data 33 ditemukan di indeks 32 (33 operasi)
# Binary search: Data 794 ditemukan di indeks 793 (9 operasi)
# Sequential search: Data 794 ditemukan di indeks 793 (794 operasi)
# Binary search: Data 4943 ditemukan di indeks 4942 (13 operasi)
# Sequential search: Data 4943 ditemukan di indeks 4942 (4943 operasi)

# %% [markdown]
# # **Penugasan 6: Proyek Mini**

# %%
def insertion_sort_key(data, key_index=0, reverse=False):
  n = len(data)
  for i in range(n):
    key = data[i]
    j = i - 1

    if reverse:
      while j >= 0 and data[j][key_index] < data[j + 1][key_index]:
        data[j], data[j + 1] = data[j + 1], data[j]
        j -= 1
    else:
      while j >= 0 and data[j][key_index] > data[j + 1][key_index]:
        data[j], data[j + 1] = data[j + 1], data[j]
        j -= 1

    data[j + 1] = key
  return data

def binary_search(data, target):
  left, right = 0, len(data)-1
  while left <= right:
    mid = (left + right) // 2
    nama, harga = data[mid]
    if harga == target:
      return f"Mahasiswa bernilai {target} bernama {nama}"
    elif harga < target:
      left = mid + 1
    else:
      right = mid - 1
  return f"Mahasiswa bernilai {target} tidak ditemukan"

daftar = []
while True:
  mahasiswa = input("Masukkan nama mahasiswa (kosongkan untuk menghitung total): ")
  if mahasiswa == "":
    break
  nilai = int(input("Masukkan nilai: "))

  daftar.append((mahasiswa, nilai))

cari_nilai = int(input("Masukkan nilai yang ingin dicari mahasiswanya: "))

daftar = insertion_sort_key(daftar, 1)
print(binary_search(daftar, cari_nilai))
# Out:
# Masukkan nama mahasiswa (kosongkan untuk menghitung total): Didi
# Masukkan nilai: 78
# Masukkan nama mahasiswa (kosongkan untuk menghitung total): Udin
# Masukkan nilai: 89
# Masukkan nama mahasiswa (kosongkan untuk menghitung total): Andi
# Masukkan nilai: 67
# Masukkan nama mahasiswa (kosongkan untuk menghitung total): Verifia
# Masukkan nilai: 74
# Masukkan nama mahasiswa (kosongkan untuk menghitung total): Dani
# Masukkan nilai: 77
# Masukkan nama mahasiswa (kosongkan untuk menghitung total): Floria
# Masukkan nilai: 94
# Masukkan nama mahasiswa (kosongkan untuk menghitung total): Amanda
# Masukkan nilai: 84
# Masukkan nama mahasiswa (kosongkan untuk menghitung total): Liubana
# Masukkan nilai: 88
# Masukkan nama mahasiswa (kosongkan untuk menghitung total): Kaitlyn
# Masukkan nilai: 92
# Masukkan nama mahasiswa (kosongkan untuk menghitung total): Azzahra
# Masukkan nilai: 91
# Masukkan nama mahasiswa (kosongkan untuk menghitung total):
# ...
